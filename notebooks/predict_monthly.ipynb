# %%
import os, sys
project_root = os.path.abspath("..")
sys.path.insert(0, project_root) # set up the working directory

# %%
from config import CONFIG

# %%
from src.data_pipeline.worldwide.build_global_dataset import build_global_dataset, load_global_dataset

# %%
year_analysis = 2015
inference_dataset = load_global_dataset(CONFIG,year=year_analysis)

# %%
specie = "aegypti"

model_year = 2015 #year of the desired incrementally trained model
from src.workflows.predict_monthly import predict_monthly
#now, predict for all 12 months
predict_monthly(CONFIG, year_analysis, specie, model_year)
