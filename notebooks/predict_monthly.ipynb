# %%
import os, sys
project_root = os.path.abspath("..")
sys.path.insert(0, project_root) # set up the working directory

# %%
from config import load_config
config = load_config()

# %%
specie = "albopictus"
import numpy as np

model_year = 2023 #year of the desired incrementally trained model
from src.workflows.predict_monthly import predict_monthly
#now, predict for all 12 months

for year in np.arange(1975, 2025):
    predict_monthly(config, year, specie, model_year)
