# %%
import os, sys
project_root = os.path.abspath("..")
sys.path.insert(0, project_root)
#from config import CONFIG
#sys.path.insert(0, CONFIG.PROJECT_ROOT)

# %%
from src.data_pipeline.training.build_training_dataset import build_training_dataset, load_training_dataset

# %%
from config import CONFIG
traing_ds = load_training_dataset(CONFIG)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40232 entries, 0 to 40231
# Data columns (total 76 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   VECTOR           40232 non-null  str
#  1   OCCURRENCE_ID    40232 non-null  int64
#  2   SOURCE_TYPE      40232 non-null  str
#  3   LOCATION_TYPE    39912 non-null  str
#  4   POLYGON_ADMIN    39308 non-null  str
#  5   Y                40232 non-null  float64
#  6   X                40232 non-null  float64
#  7   YEAR             40232 non-null  int64
#  8   COUNTRY          40232 non-null  str
#  9   COUNTRY_ID       40232 non-null  str
#  10  GAUL_AD0         40232 non-null  int64
#  11  STATUS           322 non-null    str
#  12  geometry         40232 non-null  str
#  13  mask_geometry    40232 non-null  str
#  14  t2m_01           40232 non-null  float64
#  15  t2m_02           40232 non-null  float64
#  16  t2m_03           40232 non-null  float64
#  17  t2m_04           40232 non-null  float64
#  18  t2m_05           40232 non-null  float64
#  19  t2m_06           40232 non-null  float64
#  20  t2m_07           40232 non-null  float64
#  21  t2m_08           40232 non-null  float64
#  22  t2m_09           40232 non-null  float64
#  23  t2m_10           40232 non-null  float64
#  24  t2m_11           40232 non-null  float64
#  25  t2m_12           40232 non-null  float64
#  26  tp_01            40232 non-null  float64
#  27  tp_02            40232 non-null  float64
#  28  tp_03            40232 non-null  float64
#  29  tp_04            40232 non-null  float64
#  30  tp_05            40232 non-null  float64
#  31  tp_06            40232 non-null  float64
#  32  tp_07            40232 non-null  float64
#  33  tp_08            40232 non-null  float64
#  34  tp_09            40232 non-null  float64
#  35  tp_10            40232 non-null  float64
#  36  tp_11            40232 non-null  float64
#  37  tp_12            40232 non-null  float64
#  38  d2m_01           40232 non-null  float64
#  39  d2m_02           40232 non-null  float64
#  40  d2m_03           40232 non-null  float64
#  41  d2m_04           40232 non-null  float64
#  42  d2m_05           40232 non-null  float64
#  43  d2m_06           40232 non-null  float64
#  44  d2m_07           40232 non-null  float64
#  45  d2m_08           40232 non-null  float64
#  46  d2m_09           40232 non-null  float64
#  47  d2m_10           40232 non-null  float64
#  48  d2m_11           40232 non-null  float64
#  49  d2m_12           40232 non-null  float64
#  50  si10_01          40232 non-null  float64
#  51  si10_02          40232 non-null  float64
#  52  si10_03          40232 non-null  float64
#  53  si10_04          40232 non-null  float64
#  54  si10_05          40232 non-null  float64
#  55  si10_06          40232 non-null  float64
#  56  si10_07          40232 non-null  float64
#  57  si10_08          40232 non-null  float64
#  58  si10_09          40232 non-null  float64
#  59  si10_10          40232 non-null  float64
#  60  si10_11          40232 non-null  float64
#  61  si10_12          40232 non-null  float64
#  62  Cropland         40191 non-null  float64
#  63  Urban            40191 non-null  float64
#  64  Forest           40191 non-null  float64
#  65  Barren           40191 non-null  float64
#  66  Pasture          40191 non-null  float64
#  67  Ocean            40191 non-null  float64
#  68  Water            40191 non-null  float64
#  69  Shrub            40191 non-null  float64
#  70  area_land_km     40193 non-null  float64
#  71  area_total_km    40193 non-null  float64
#  72  hilda_polygon    40193 non-null  str
#  73  ghsl_pop_counts  40232 non-null  float64
#  74  ghsl_polygon     40232 non-null  str
#  75  pop_density      40192 non-null  float64
# dtypes: float64(62), int64(3), str(11)
# memory usage: 23.3 MB
# None
# ['VECTOR', 'OCCURRENCE_ID', 'SOURCE_TYPE', 'LOCATION_TYPE', 'POLYGON_ADMIN', 'Y', 'X', 'YEAR', 'COUNTRY', 'COUNTRY_ID', 'GAUL_AD0', 'STATUS', 'geometry', 'mask_geometry', 't2m_01', 't2m_02', 't2m_03', 't2m_04', 't2m_05', 't2m_06', 't2m_07', 't2m_08', 't2m_09', 't2m_10', 't2m_11', 't2m_12', 'tp_01', 'tp_02', 'tp_03', 'tp_04', 'tp_05', 'tp_06', 'tp_07', 'tp_08', 'tp_09', 'tp_10', 'tp_11', 'tp_12', 'd2m_01', 'd2m_02', 'd2m_03', 'd2m_04', 'd2m_05', 'd2m_06', 'd2m_07', 'd2m_08', 'd2m_09', 'd2m_10', 'd2m_11', 'd2m_12', 'si10_01', 'si10_02', 'si10_03', 'si10_04', 'si10_05', 'si10_06', 'si10_07', 'si10_08', 'si10_09', 'si10_10', 'si10_11', 'si10_12', 'Cropland', 'Urban', 'Forest', 'Barren', 'Pasture', 'Ocean', 'Water', 'Shrub', 'area_land_km', 'area_total_km', 'hilda_polygon', 'ghsl_pop_counts', 'ghsl_polygon', 'pop_density']

# %%
from src.workflows.train_monthly import train_climademic_monthly_model

specie = "albopictus"
gmod_year_start = 2015
gmod_year_end = 2015
train_climademic_monthly_model(CONFIG, specie, gmod_year_start, gmod_year_end)
